# %% [markdown]
# ## Convertir le notebook Fonction_utils en script Python

# %%
import nbformat
from nbconvert import PythonExporter
import os

# Définition des chemins 

notebook_path = "/home/sacko/Documents/Chatbot-Rh-Rag/Scripts/app_streamlit.ipynb"
script_path = "/home/sacko/Documents/Chatbot-Rh-Rag/Scripts/app_streamlit.py"

# notebook_path = "/home/sacko/Documents/Chatbot-Rh-Rag/Scripts/rag_query.ipynb"
# script_path = "/home/sacko/Documents/Chatbot-Rh-Rag/Scripts/rag_query.py"


# Fonction pour convertir le notebook en script Python
def convert_notebook_to_script(notebook_path, script_path):
    with open(notebook_path) as f:
        nb = nbformat.read(f, as_version=4)
        exporter = PythonExporter()
        script, _ = exporter.from_notebook_node(nb)

    with open(script_path, 'w') as f:
        f.write(script)

# Exécuter la conversion
convert_notebook_to_script(notebook_path, script_path)
print(f"Le notebook {notebook_path} a été converti en script Python.")
# Out:
# Le notebook /home/sacko/Documents/Chatbot-Rh-Rag/Scripts/rag_query.ipynb a été converti en script Python.
